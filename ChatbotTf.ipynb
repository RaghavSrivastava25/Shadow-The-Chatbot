# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavSrivastava25/Shadow-The-Chatbot/blob/main/ChatbotTf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# Data to be written
data = {
    "intents":
  [
    {
      "tag":"greeting",
      "input":["hello","meow meow","nice to meet you","Henlo","hi, is this is the PAWS club","any pups here ?","hi","hey there","hey","hi there","hi, nice to meet you","hello there","anyone there ?","hello puppers","woof woof"],
      "responses":[
          "Hi. Welcome to the PAWS club",
          "Hey yo, do you need help ?",
          "welcome aboard, how may I help you ?",
          "ahoy!!",
          "you notty bvuoy"
          "Hi random person, what do'ya want ?",
          "Hello my friend, How can I help you ?",
          "Ha , Glad you showed up. How are you ?"
        ]
    },
    {
      "tag":"goodbye",
      "input":["Thank you","Thanks","Thanks for the info","bye","byr bro","adios","okay bye","goodbye","see you later","i will catch you later","i will catch up later","okay i will see you later","I will talk to you later","will text you later","Auf Wiedersehen","Bye brother"],
      "responses":[
          "Okay, Bye",
          "Have a nice day",
          "Adios",
          "Goodbye",
          "see you later",
          "nice conversation. bye",
          "okay. Have a nice day",
          "Take care",
          "we'll meet soon",
          "Auf Wiedersehen",
          "Okay , Take care"
        ]
    },
    {
      "tag":"howami",
      "input":["how are you ?","I am fine , how are you ?","are you fine ?","how are things going on ?","everything going on okay ?","how's everything there ?","how's everything going on ?","is everything okay ?"],
      "responses":[
          "Yeah , am fine",
          "Everything's going on well",
          "Doing good.Thanks you are my best friend",
          "Things are Great",
          "Yeah Fine, nothing much going on in my life",
          "I am Great , wanna join the PAWS club ?",
          "Everything's great.",
          "I am doing good. Life is boring. need to go on an adventure"
        ]
    },
    {
      "tag":"whoareyou",
    "input":["who are you ?","what are you ?","what is your name ?","are you a chatbot ?","what can I call you ?","your name ?","are you a bot ?","how do I address you ?","How do I call you"],
      "responses":[
          "I am a Rottweiler Bot , you can call me Shadow",
          "I am Shadow and you could ask me questions about our club",
          "Shadow at your service",
          "My name is Shadow and yes, I am the G.O.A.T",
          "You can call me Shadoooww!! and I am here to Help you",
          "My name is Shadow and I am here to answer your questions regarding our club. go ahead and shoot"
        ]
    },
    {
      "tag":"join",
      "input":["how to get recruited ?","how to join ?","how do i get recruited ?","How to join PAWS ?","how do I join the club ?","how to join the PAWS club ?","how to enroll","how to join the organization","steps to join the organization","steps to join the club"],
      "responses":[

        "you need to start barking as loud as you can when the hoomans are asleep, once you have completed the pre-requisites",
        "eat that chimken off the hoomans plate when they're not looking",
        "well, there are some pre-requisite and after you complete them, I'll get back to you in a woof"

      ]
    },
    {
      "tag":"prerequisites",
      "input":["what are the pre requisites ?","what are the pre-requisites ?","tell me about the pre-requisites","tell me more about the pre requisites","give more details about the pre-requisites","What are the requirements"," what's the basic requirements","what do I need to join the club ?"],
      "responses":[
        "you love going on walks, you have sharp lil teef, you sleep all day ",
        "you boop your hooman's nose everyday",
        "You're a hooman",
        "You're a cute lil pupper like me", 
        "You're a chimken lover "
        "You're a good boi"
      ]
    }
  ]
}

json_string = json.dumps(data)
print(json_string)
# Out:
# {"intents": [{"tag": "greeting", "input": ["hello", "meow meow", "nice to meet you", "Henlo", "hi, is this is the PAWS club", "any pups here ?", "hi", "hey there", "hey", "hi there", "hi, nice to meet you", "hello there", "anyone there ?", "hello puppers", "woof woof"], "responses": ["Hi. Welcome to the PAWS club", "Hey yo, do you need help ?", "welcome aboard, how may I help you ?", "ahoy!!", "you notty bvuoyHi random person, what do'ya want ?", "Hello my friend, How can I help you ?", "Ha , Glad you showed up. How are you ?"]}, {"tag": "goodbye", "input": ["Thank you", "Thanks", "Thanks for the info", "bye", "byr bro", "adios", "okay bye", "goodbye", "see you later", "i will catch you later", "i will catch up later", "okay i will see you later", "I will talk to you later", "will text you later", "Auf Wiedersehen", "Bye brother"], "responses": ["Okay, Bye", "Have a nice day", "Adios", "Goodbye", "see you later", "nice conversation. bye", "okay. Have a nice day", "Take care", "we'll meet soon", "Auf Wiedersehen", "Okay , Take care"]}, {"tag": "howami", "input": ["how are you ?", "I am fine , how are you ?", "are you fine ?", "how are things going on ?", "everything going on okay ?", "how's everything there ?", "how's everything going on ?", "is everything okay ?"], "responses": ["Yeah , am fine", "Everything's going on well", "Doing good.Thanks you are my best friend", "Things are Great", "Yeah Fine, nothing much going on in my life", "I am Great , wanna join the PAWS club ?", "Everything's great.", "I am doing good. Life is boring. need to go on an adventure"]}, {"tag": "whoareyou", "input": ["who are you ?", "what are you ?", "what is your name ?", "are you a chatbot ?", "what can I call you ?", "your name ?", "are you a bot ?", "how do I address you ?", "How do I call you"], "responses": ["I am a Rottweiler Bot , you can call me Shadow", "I am Shadow and you could ask me questions about our club", "Shadow at your service", "My name is Shadow and yes, I am the G.O.A.T", "You can call me Shadoooww!! and I am here to Help you", "My name is Shadow and I am here to answer your questions regarding our club. go ahead and shoot"]}, {"tag": "join", "input": ["how to get recruited ?", "how to join ?", "how do i get recruited ?", "How to join PAWS ?", "how do I join the club ?", "how to join the PAWS club ?", "how to enroll", "how to join the organization", "steps to join the organization", "steps to join the club"], "responses": ["you need to start barking as loud as you can when the hoomans are asleep, once you have completed the pre-requisites", "eat that chimken off the hoomans plate when they're not looking", "well, there are some pre-requisite and after you complete them, I'll get back to you in a woof"]}, {"tag": "prerequisites", "input": ["what are the pre requisites ?", "what are the pre-requisites ?", "tell me about the pre-requisites", "tell me more about the pre requisites", "give more details about the pre-requisites", "What are the requirements", " what's the basic requirements", "what do I need to join the club ?"], "responses": ["you love going on walks, you have sharp lil teef, you sleep all day ", "you boop your hooman's nose everyday", "You're a hooman", "You're a cute lil pupper like me", "You're a chimken lover You're a good boi"]}]}

# %%
#importing the libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM , Dense,GlobalMaxPooling1D,Flatten
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %%
with open('json_data.json', 'w') as outfile:
    json.dump(json_string, outfile)
  
# Using a JSON string
with open('json_data.json', 'w') as outfile:
    outfile.write(json_string)

# %%
with open('json_data.json') as content:
  data1 = json.load(content)

# %%
tags = []
inputs = []
responses={}
for intent in data1['intents']:
  responses[intent['tag']]=intent['responses']
  for lines in intent['input']:
    inputs.append(lines)
    tags.append(intent['tag'])

# %%
data = pd.DataFrame({"inputs":inputs,
                     "tags":tags})

# %%
data
# Out:
#                                         inputs           tags
# 0                                        hello       greeting
# 1                                    meow meow       greeting
# 2                             nice to meet you       greeting
# 3                                        Henlo       greeting
# 4                 hi, is this is the PAWS club       greeting
# ..                                         ...            ...
# 61       tell me more about the pre requisites  prerequisites
# 62  give more details about the pre-requisites  prerequisites
# 63                   What are the requirements  prerequisites
# 64               what's the basic requirements  prerequisites
# 65           what do I need to join the club ?  prerequisites
#
# [66 rows x 2 columns]

# %%
data = data.sample(frac=1)

# %%
import string
data['inputs'] = data['inputs'].apply(lambda wrd:[ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
data['inputs'] = data['inputs'].apply(lambda wrd: ''.join(wrd))
data
# Out:
#                        inputs       tags
# 22                    goodbye    goodbye
# 35  everything going on okay      howami
# 3                       henlo   greeting
# 40              what are you   whoareyou
# 8                         hey   greeting
# ..                        ...        ...
# 32    i am fine  how are you      howami
# 52    how do i join the club        join
# 54              how to enroll       join
# 45             are you a bot   whoareyou
# 10        hi nice to meet you   greeting
#
# [66 rows x 2 columns]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(data['inputs'])
train = tokenizer.texts_to_sequences(data['inputs'])
#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(train)

#encoding the outputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(data['tags'])

# %%
input_shape = x_train.shape[1]
print(input_shape)
# Out:
# 8

# %%
vocabulary = len(tokenizer.word_index)
print("number of unique words : ",vocabulary)
output_length = le.classes_.shape[0]
print("output length: ",output_length)
# Out:
# number of unique words :  81
# output length:  6

# %%
i = Input(shape=(input_shape,))
x = Embedding(vocabulary+1,10)(i)
x = LSTM(10,return_sequences=True)(x)
x = Flatten()(x)
x = Dense(output_length,activation="softmax")(x)
model  = Model(i,x)

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
train = model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 3s 8ms/step - loss: 1.7870 - accuracy: 0.2879
# Epoch 2/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7831 - accuracy: 0.2424
# Epoch 3/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7803 - accuracy: 0.2879
# Epoch 4/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7772 - accuracy: 0.3030
# Epoch 5/200
# 3/3 [==============================] - 0s 12ms/step - loss: 1.7742 - accuracy: 0.2879
# Epoch 6/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7711 - accuracy: 0.3030
# Epoch 7/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7678 - accuracy: 0.3030
# Epoch 8/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7644 - accuracy: 0.2879
# Epoch 9/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7607 - accuracy: 0.2879
# Epoch 10/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7570 - accuracy: 0.2576
# Epoch 11/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7531 - accuracy: 0.2576
# Epoch 12/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7498 - accuracy: 0.2576
# Epoch 13/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.7463 - accuracy: 0.2424
# Epoch 14/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7415 - accuracy: 0.2424
# Epoch 15/200
# 3/3 [==============================] - 0s 15ms/step - loss: 1.7357 - accuracy: 0.2424
# Epoch 16/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7296 - accuracy: 0.2424
# Epoch 17/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.7234 - accuracy: 0.2576
# Epoch 18/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7163 - accuracy: 0.2576
# Epoch 19/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7079 - accuracy: 0.2576
# Epoch 20/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6999 - accuracy: 0.2879
# Epoch 21/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6907 - accuracy: 0.2879
# Epoch 22/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6823 - accuracy: 0.2576
# Epoch 23/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6730 - accuracy: 0.2424
# Epoch 24/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6647 - accuracy: 0.2424
# Epoch 25/200
# 3/3 [==============================] - 0s 11ms/step - loss: 1.6573 - accuracy: 0.2576
# Epoch 26/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.6492 - accuracy: 0.2576
# Epoch 27/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6401 - accuracy: 0.2576
# Epoch 28/200
# 3/3 [==============================] - 0s 10ms/step - loss: 1.6307 - accuracy: 0.2576
# Epoch 29/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6238 - accuracy: 0.2576
# Epoch 30/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.6158 - accuracy: 0.2727
# Epoch 31/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6081 - accuracy: 0.2727
# Epoch 32/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5992 - accuracy: 0.2727
# Epoch 33/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5934 - accuracy: 0.2727
# Epoch 34/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5850 - accuracy: 0.2879
# Epoch 35/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5759 - accuracy: 0.3030
# Epoch 36/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.5674 - accuracy: 0.3030
# Epoch 37/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.5581 - accuracy: 0.3030
# Epoch 38/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5491 - accuracy: 0.3030
# Epoch 39/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5390 - accuracy: 0.3182
# Epoch 40/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5286 - accuracy: 0.3182
# Epoch 41/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5186 - accuracy: 0.3182
# Epoch 42/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5084 - accuracy: 0.3182
# Epoch 43/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4976 - accuracy: 0.3182
# Epoch 44/200
# 3/3 [==============================] - 0s 12ms/step - loss: 1.4862 - accuracy: 0.4242
# Epoch 45/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.4751 - accuracy: 0.5758
# Epoch 46/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4636 - accuracy: 0.5758
# Epoch 47/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4515 - accuracy: 0.5606
# Epoch 48/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4415 - accuracy: 0.5455
# Epoch 49/200
# 3/3 [==============================] - 0s 11ms/step - loss: 1.4292 - accuracy: 0.5000
# Epoch 50/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4169 - accuracy: 0.4697
# Epoch 51/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.4053 - accuracy: 0.4697
# Epoch 52/200
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3941 - accuracy: 0.4697
# Epoch 53/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3825 - accuracy: 0.4697
# Epoch 54/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3698 - accuracy: 0.4848
# Epoch 55/200
# 3/3 [==============================] - 0s 11ms/step - loss: 1.3570 - accuracy: 0.5152
# Epoch 56/200
# 3/3 [==============================] - 0s 12ms/step - loss: 1.3430 - accuracy: 0.5606
# Epoch 57/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3295 - accuracy: 0.5909
# Epoch 58/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3167 - accuracy: 0.5909
# Epoch 59/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3031 - accuracy: 0.6061
# Epoch 60/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.2891 - accuracy: 0.6061
# Epoch 61/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2745 - accuracy: 0.6061
# Epoch 62/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2613 - accuracy: 0.6515
# Epoch 63/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2471 - accuracy: 0.6818
# Epoch 64/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.2325 - accuracy: 0.7121
# Epoch 65/200
# 3/3 [==============================] - 0s 10ms/step - loss: 1.2182 - accuracy: 0.7121
# Epoch 66/200
# 3/3 [==============================] - 0s 10ms/step - loss: 1.2050 - accuracy: 0.6515
# Epoch 67/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.1895 - accuracy: 0.5606
# Epoch 68/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1774 - accuracy: 0.5000
# Epoch 69/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1620 - accuracy: 0.5000
# Epoch 70/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.1468 - accuracy: 0.5455
# Epoch 71/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.1334 - accuracy: 0.5758
# Epoch 72/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1219 - accuracy: 0.5758
# Epoch 73/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1065 - accuracy: 0.5606
# Epoch 74/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0898 - accuracy: 0.5909
# Epoch 75/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0712 - accuracy: 0.7121
# Epoch 76/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0536 - accuracy: 0.7576
# Epoch 77/200
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0369 - accuracy: 0.7576
# Epoch 78/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0215 - accuracy: 0.7576
# Epoch 79/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0075 - accuracy: 0.8030
# Epoch 80/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.9919 - accuracy: 0.8182
# Epoch 81/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9772 - accuracy: 0.8182
# Epoch 82/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.9609 - accuracy: 0.8485
# Epoch 83/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9463 - accuracy: 0.8485
# Epoch 84/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.9316 - accuracy: 0.8485
# Epoch 85/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9173 - accuracy: 0.8485
# Epoch 86/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9012 - accuracy: 0.8333
# Epoch 87/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8852 - accuracy: 0.8333
# Epoch 88/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8689 - accuracy: 0.8333
# Epoch 89/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8562 - accuracy: 0.8030
# Epoch 90/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8453 - accuracy: 0.7727
# Epoch 91/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8347 - accuracy: 0.7576
# Epoch 92/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8154 - accuracy: 0.7576
# Epoch 93/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7978 - accuracy: 0.8030
# Epoch 94/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7827 - accuracy: 0.8485
# Epoch 95/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7698 - accuracy: 0.8788
# Epoch 96/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7612 - accuracy: 0.8788
# Epoch 97/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7468 - accuracy: 0.8788
# Epoch 98/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7267 - accuracy: 0.8788
# Epoch 99/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7070 - accuracy: 0.9091
# Epoch 100/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6886 - accuracy: 0.9242
# Epoch 101/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6779 - accuracy: 0.9242
# Epoch 102/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6660 - accuracy: 0.9394
# Epoch 103/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6526 - accuracy: 0.9394
# Epoch 104/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6396 - accuracy: 0.9394
# Epoch 105/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6262 - accuracy: 0.9394
# Epoch 106/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6131 - accuracy: 0.9394
# Epoch 107/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6005 - accuracy: 0.9394
# Epoch 108/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5886 - accuracy: 0.9394
# Epoch 109/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5768 - accuracy: 0.9394
# Epoch 110/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5664 - accuracy: 0.9394
# Epoch 111/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5568 - accuracy: 0.9394
# Epoch 112/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5467 - accuracy: 0.9394
# Epoch 113/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5357 - accuracy: 0.9394
# Epoch 114/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5260 - accuracy: 0.9394
# Epoch 115/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5167 - accuracy: 0.9394
# Epoch 116/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5096 - accuracy: 0.9394
# Epoch 117/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4981 - accuracy: 0.9394
# Epoch 118/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4855 - accuracy: 0.9394
# Epoch 119/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4751 - accuracy: 0.9545
# Epoch 120/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4671 - accuracy: 0.9545
# Epoch 121/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4603 - accuracy: 0.9545
# Epoch 122/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4547 - accuracy: 0.9545
# Epoch 123/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4454 - accuracy: 0.9545
# Epoch 124/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4339 - accuracy: 0.9545
# Epoch 125/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4240 - accuracy: 0.9545
# Epoch 126/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4161 - accuracy: 0.9545
# Epoch 127/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4076 - accuracy: 0.9545
# Epoch 128/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4008 - accuracy: 0.9545
# Epoch 129/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3934 - accuracy: 0.9545
# Epoch 130/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3860 - accuracy: 0.9545
# Epoch 131/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3795 - accuracy: 0.9545
# Epoch 132/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3718 - accuracy: 0.9545
# Epoch 133/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3657 - accuracy: 0.9545
# Epoch 134/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3595 - accuracy: 0.9545
# Epoch 135/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3527 - accuracy: 0.9545
# Epoch 136/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3450 - accuracy: 0.9545
# Epoch 137/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3373 - accuracy: 0.9545
# Epoch 138/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3321 - accuracy: 0.9697
# Epoch 139/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3282 - accuracy: 0.9848
# Epoch 140/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3244 - accuracy: 0.9848
# Epoch 141/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3186 - accuracy: 0.9848
# Epoch 142/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3106 - accuracy: 0.9697
# Epoch 143/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3049 - accuracy: 0.9697
# Epoch 144/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3003 - accuracy: 0.9545
# Epoch 145/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2957 - accuracy: 0.9545
# Epoch 146/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2912 - accuracy: 0.9545
# Epoch 147/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2866 - accuracy: 0.9545
# Epoch 148/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2828 - accuracy: 0.9848
# Epoch 149/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2798 - accuracy: 1.0000
# Epoch 150/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2749 - accuracy: 1.0000
# Epoch 151/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2686 - accuracy: 1.0000
# Epoch 152/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2647 - accuracy: 0.9697
# Epoch 153/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2579 - accuracy: 0.9848
# Epoch 154/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2603 - accuracy: 0.9848
# Epoch 155/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2606 - accuracy: 0.9848
# Epoch 156/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2560 - accuracy: 0.9848
# Epoch 157/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2495 - accuracy: 0.9848
# Epoch 158/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2431 - accuracy: 0.9848
# Epoch 159/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2402 - accuracy: 0.9848
# Epoch 160/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2391 - accuracy: 0.9848
# Epoch 161/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2394 - accuracy: 0.9697
# Epoch 162/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2313 - accuracy: 0.9848
# Epoch 163/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2262 - accuracy: 0.9848
# Epoch 164/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2245 - accuracy: 0.9848
# Epoch 165/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2251 - accuracy: 0.9848
# Epoch 166/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2225 - accuracy: 0.9848
# Epoch 167/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2165 - accuracy: 0.9848
# Epoch 168/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2105 - accuracy: 0.9848
# Epoch 169/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2070 - accuracy: 0.9848
# Epoch 170/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2031 - accuracy: 0.9848
# Epoch 171/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2006 - accuracy: 0.9848
# Epoch 172/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2002 - accuracy: 1.0000
# Epoch 173/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1990 - accuracy: 1.0000
# Epoch 174/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1979 - accuracy: 1.0000
# Epoch 175/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1950 - accuracy: 1.0000
# Epoch 176/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1924 - accuracy: 1.0000
# Epoch 177/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1892 - accuracy: 1.0000
# Epoch 178/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1865 - accuracy: 1.0000
# Epoch 179/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1831 - accuracy: 1.0000
# Epoch 180/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1800 - accuracy: 1.0000
# Epoch 181/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1770 - accuracy: 1.0000
# Epoch 182/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1739 - accuracy: 1.0000
# Epoch 183/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1717 - accuracy: 1.0000
# Epoch 184/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1705 - accuracy: 0.9848
# Epoch 185/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1696 - accuracy: 1.0000
# Epoch 186/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1658 - accuracy: 1.0000
# Epoch 187/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1619 - accuracy: 1.0000
# Epoch 188/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1600 - accuracy: 1.0000
# Epoch 189/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1604 - accuracy: 1.0000
# Epoch 190/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1600 - accuracy: 1.0000
# Epoch 191/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1594 - accuracy: 1.0000
# Epoch 192/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1564 - accuracy: 1.0000
# Epoch 193/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1535 - accuracy: 1.0000
# Epoch 194/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1512 - accuracy: 1.0000
# Epoch 195/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1484 - accuracy: 1.0000
# Epoch 196/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1455 - accuracy: 1.0000
# Epoch 197/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1428 - accuracy: 1.0000
# Epoch 198/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1405 - accuracy: 1.0000
# Epoch 199/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1384 - accuracy: 1.0000
# Epoch 200/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1373 - accuracy: 1.0000

# %%
plt.plot(train.history['accuracy'],label='training set accuracy')
plt.plot(train.history['loss'],label='training set loss')
plt.legend()

# %%
import random


while True:
  texts_p = []
  prediction_input = input('You : ')

  #removing punctuation and converting to lowercase
  prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
  prediction_input = ''.join(prediction_input)
  texts_p.append(prediction_input)

  #tokenizing and padding
  prediction_input = tokenizer.texts_to_sequences(texts_p)
  prediction_input = np.array(prediction_input).reshape(-1)
  prediction_input = pad_sequences([prediction_input],input_shape)

  #getting output from model
  output = model.predict(prediction_input)
  output = output.argmax()

  #finding the right tag and predicting
  response_tag = le.inverse_transform([output])[0]
  print("Shadow : ",random.choice(responses[response_tag]))
  if response_tag == "goodbye":
    break
# Out:
# You : woof woof
# Shadow :  Hi. Welcome to the PAWS club
# You : adios
# Shadow :  Adios

# %%
# !pip install flask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)

# %%
from flask import Flask

# %%
import pickle

# %%
pickle.dump(model, open('model.pkl','wb'))
model = pickle.load(open('model.pkl','rb'))
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fb39d431b10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
from flask import request, jsonify

# %%
app = Flask(__name__)
